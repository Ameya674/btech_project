# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from copy import deepcopy as dc
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import import_ipynb
from helpers import train_and_validate, count_parameters, plot_loss_comparison, plot_test_predictions, compare_mse_loss
import time
import matplotlib.pyplot as plt
# Out:
# importing Jupyter notebook from helpers.ipynb

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
window_size = 24
batch_size = 100
input_size = 1
hidden_size = 100
num_classes = 1
learning_rate = 0.005
epochs = 100
criterion = nn.MSELoss()

# %%
def root_mean_squared_error(actual, predicted):
    actual = torch.tensor(actual, dtype=torch.float32)
    predicted = torch.tensor(predicted, dtype=torch.float32)
    
    if actual.shape != predicted.shape:
        raise ValueError("Tensors must have the same shape.")
    
    mse = torch.mean((actual - predicted)**2)
    
    return (mse.item() ** 0.5)

# %%
df = pd.read_csv("./data/clean_woodland_data.csv")
df
# Out:
#                       Date    P (kW)
# 0      2022-01-01 06:00:00  0.000000
# 1      2022-01-01 07:00:00  0.410583
# 2      2022-01-01 08:00:00  2.762083
# 3      2022-01-01 09:00:00  5.461250
# 4      2022-01-01 10:00:00  8.356167
# ...                    ...       ...
# 25642  2024-12-04 16:00:00  6.669250
# 25643  2024-12-04 17:00:00  2.849417
# 25644  2024-12-04 18:00:00  0.398083
# 25645  2024-12-04 19:00:00  0.000000
# 25646  2024-12-04 20:00:00  0.000000
#
# [25647 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25647 entries, 0 to 25646
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    25647 non-null  object
#  1   P (kW)  25647 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 400.9+ KB

# %%
df = df[["Date", "P (kW)"]]
train_df = df.iloc[:-24]
test = df.iloc[-24:]

# %%
def prepare_dataframe(df, n_steps):
    df = dc(df)
    
    df.set_index('Date', inplace=True)
    
    for i in range(1, n_steps+1):
        df[f'P (kW)(t-{i})'] = df['P (kW)'].shift(i)
        
    df.dropna(inplace=True)
    
    return df

# %%
new_df = prepare_dataframe(train_df, window_size)
new_df = new_df.to_numpy()
new_df
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.7620833e+00,
#         4.1058330e-01, 0.0000000e+00],
#        [7.4316670e-01, 0.0000000e+00, 0.0000000e+00, ..., 5.4612500e+00,
#         2.7620833e+00, 4.1058330e-01],
#        [4.3818335e+00, 7.4316670e-01, 0.0000000e+00, ..., 8.3561670e+00,
#         5.4612500e+00, 2.7620833e+00],
#        ...,
#        [3.0066670e-01, 3.0534167e+00, 7.5616665e+00, ..., 0.0000000e+00,
#         1.0015000e-01, 2.0030000e-01],
#        [1.5033335e-01, 3.0066670e-01, 3.0534167e+00, ..., 9.8000000e-04,
#         0.0000000e+00, 1.0015000e-01],
#        [0.0000000e+00, 1.5033335e-01, 3.0066670e-01, ..., 1.9600000e-03,
#         9.8000000e-04, 0.0000000e+00]])

# %%
X = new_df[:, 1:]
y = new_df[:, 0]

# %%
X.shape, y.shape
# Out:
# ((25599, 24), (25599,))

# %%
split_index = int(len(X) * 0.8)

# %%
X_train = X[:split_index]
X_val = X[split_index:]

y_train = y[:split_index]
y_val = y[split_index:]

X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((20479, 24), (5120, 24), (20479,), (5120,))

# %%
X_train = X_train.reshape((-1, window_size, 1))
X_val = X_val.reshape((-1, window_size, 1))

y_train = y_train.reshape((-1, 1))
y_val = y_val.reshape((-1, 1))

X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((20479, 24, 1), (5120, 24, 1), (20479, 1), (5120, 1))

# %%
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_val = torch.tensor(X_val).float()
y_val = torch.tensor(y_val).float()

X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# (torch.Size([20479, 24, 1]),
#  torch.Size([5120, 24, 1]),
#  torch.Size([20479, 1]),
#  torch.Size([5120, 1]))

# %%
class SolarData(Dataset):

    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

# %%
train = SolarData(X_train, y_train)
val = SolarData(X_val, y_val)

# %%
train_loader = DataLoader(train, batch_size = batch_size, shuffle = True)
val_loader = DataLoader(val, batch_size = batch_size, shuffle = False)

# %%
for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([100, 24, 1]) torch.Size([100, 1])

# %%
class CustomNet(nn.Module):

    def __init__(self, input_size: int, hidden_size: int, num_classes: int):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_classes = num_classes
        self.W = nn.Parameter(torch.Tensor(input_size, hidden_size), requires_grad = True)
        self.lstm = nn.GRU(hidden_size, hidden_size, batch_first = True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        x = torch.tanh(x @ self.W)
        x_, h = self.lstm(x)
        out = self.fc(x_[:, -1, :])
        return out

# %%
customnet = CustomNet(input_size, hidden_size, num_classes).to(device)
customnet_optimizer = torch.optim.Adam(customnet.parameters(), lr = learning_rate)

# %%
total_customnet_parameters = count_parameters(customnet)

# %%
customnet_train_loss_array = []
customnet_val_loss_array = []

# %%
customnet_start_time = time.time()
train_and_validate(epochs, device, customnet, train_loader, val_loader, criterion, customnet_optimizer, customnet_train_loss_array, customnet_val_loss_array)
customnet_end_time = time.time()
customnet_total_training_time = customnet_end_time - customnet_start_time
customnet_avg_training_time_per_epoch = customnet_total_training_time / epochs
# Out:
# Epoch no.: 1 | Training Loss: 3.5373051500901944 | Validation Loss: 0.38874647095060655
# Epoch no.: 2 | Training Loss: 1.276439791917801 | Validation Loss: 0.12889391143555537
# Epoch no.: 3 | Training Loss: 1.1643891129551864 | Validation Loss: 0.18084561714651778
# Epoch no.: 4 | Training Loss: 1.1077229430035846 | Validation Loss: 0.14872081973589957
# Epoch no.: 5 | Training Loss: 1.0833077038206704 | Validation Loss: 0.06916426890753567
# Epoch no.: 6 | Training Loss: 1.0720330187460272 | Validation Loss: 0.09000875607867223
# Epoch no.: 7 | Training Loss: 1.0699220090377621 | Validation Loss: 0.17298403625878003
# Epoch no.: 8 | Training Loss: 1.071151849264052 | Validation Loss: 0.09651392768137157
# Epoch no.: 9 | Training Loss: 1.0738911653437266 | Validation Loss: 0.11366801779681387
# Epoch no.: 10 | Training Loss: 1.0379141529885734 | Validation Loss: 0.08731498041351397
# Epoch no.: 11 | Training Loss: 1.1016824374838574 | Validation Loss: 0.11645671597216278
# Epoch no.: 12 | Training Loss: 1.0657088830703643 | Validation Loss: 0.12141057754678723
# Epoch no.: 13 | Training Loss: 1.0338347650155788 | Validation Loss: 0.10796982046360007
# Epoch no.: 14 | Training Loss: 0.9961113862875032 | Validation Loss: 0.08559877678859405
# Epoch no.: 15 | Training Loss: 1.0611431108742226 | Validation Loss: 0.09842341441589479
# Epoch no.: 16 | Training Loss: 1.0117359298031505 | Validation Loss: 0.11530644870631826
# Epoch no.: 17 | Training Loss: 0.9728423468950318 | Validation Loss: 0.10678179297918597
# Epoch no.: 18 | Training Loss: 1.0335458418218102 | Validation Loss: 0.05842143066064846
# Epoch no.: 19 | Training Loss: 1.0212130912920323 | Validation Loss: 0.09330775085590386
# Epoch no.: 87 | Training Loss: 0.938921295724264 | Validation Loss: 0.09977565870996422
# Epoch no.: 88 | Training Loss: 0.9411979651305734 | Validation Loss: 0.09157047049778227
# Epoch no.: 89 | Training Loss: 0.9236627607810788 | Validation Loss: 0.08019618791303611
# Epoch no.: 90 | Training Loss: 0.9341894433265779 | Validation Loss: 0.15059135349628588
# Epoch no.: 91 | Training Loss: 0.9392925729111927 | Validation Loss: 0.10051053845269892
# Epoch no.: 92 | Training Loss: 0.9342999834113005 | Validation Loss: 0.07244885267853253
# Epoch no.: 93 | Training Loss: 0.9184623482750683 | Validation Loss: 0.08190859461165718
# Epoch no.: 94 | Training Loss: 0.9667878104419243 | Validation Loss: 0.16387298392454305
# Epoch no.: 95 | Training Loss: 0.9367909376214191 | Validation Loss: 0.09749192591810313
# Epoch no.: 96 | Training Loss: 0.9416096927189246 | Validation Loss: 0.07209119363002313
# Epoch no.: 97 | Training Loss: 0.9533655921860439 | Validation Loss: 0.10456205882470525
# Epoch no.: 98 | Training Loss: 1.0003627547403662 | Validation Loss: 0.11825810910802549
# Epoch no.: 99 | Training Loss: 0.9562681382749139 | Validation Loss: 0.07503439903107043
# Epoch no.: 100 | Training Loss: 0.9340910436176673 | Validation Loss: 0.09278470642815452

# %%
print()
print()
print("------------------------------------------------------------")
print(f"Total Parameters:     CustomNet: {total_customnet_parameters}")
print()
print(f"Total Training Time:     CustomNet: {customnet_total_training_time:.2f}s")
print()
print(f"Average Training Time Per Epoch:     CustomNet: {customnet_avg_training_time_per_epoch:.2f}s")

print("------------------------------------------------------------")
# Out:
# ------------------------------------------------------------
# Total Parameters:     CustomNet: 60801
#
# Total Training Time:     CustomNet: 97.67s
#
# Average Training Time Per Epoch:     CustomNet: 0.98s
# ------------------------------------------------------------

# %%
plot_loss_comparison(epochs, customnet_train_loss_array, customnet_val_loss_array, "CustomNet Training Loss", "CustomNet Validation Loss", "Training vs Validation Loss")

# %%
customnet.eval()
last_24_values_test = y_val[-window_size:]
last_24_values_test = torch.tensor(last_24_values_test, dtype=torch.float32).unsqueeze(0).to(device)
predictions_test = []

for i in range(window_size):
    # Make the prediction
    with torch.no_grad():
        pred_test = customnet(last_24_values_test)
    
    # Store the prediction
    predictions_test.append(pred_test.item())
    
    # Shift the values to the left and add the predicted value to the last_24_values_test for the next iteration
    last_24_values_test = torch.cat((last_24_values_test[:, 1:], pred_test.unsqueeze(1)), dim=1)

# Convert predictions_test to a numpy array
predictions_test = np.array(predictions_test)
# Out:
# C:\Users\itadmin\AppData\Local\Temp\ipykernel_13224\1908420732.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   last_24_values_test = torch.tensor(last_24_values_test, dtype=torch.float32).unsqueeze(0).to(device)

# %%
plt.figure(figsize=(12, 6))
plt.plot(test['Date'], test['P (kW)'], 'g', label='True Values')
plt.plot(test['Date'], predictions_test, 'b', label='Predictions')
plt.title('True Values vs CustomNet Predictions')
plt.xlabel('Date')
plt.ylabel('P (kW)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
mse = root_mean_squared_error(test["P (kW)"].values, predictions_test)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 2.1281962199344338
